# %%
import os
import sys

import torch
from PIL import Image

sys.path.append("../")
from src import Predictor

# %%
model_log_dir = "../model_logs"
restore_version = "train_240422160848"

# %%
log_dir = os.path.join(model_log_dir, restore_version)

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
predictor = Predictor.from_pretrained(log_dir, device=device)

# %%
lq_image_path = "../data/val/LQ/00007.png"
lq_image = Image.open(lq_image_path)

# %%
lq_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128>

# %%
predictor.predict(lq_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
